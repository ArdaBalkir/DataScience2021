# %%
from bokeh.plotting import figure, output_file, show

from bokeh.tile_providers import get_provider, WIKIMEDIA, CARTODBPOSITRON, STAMEN_TERRAIN, STAMEN_TONER, ESRI_IMAGERY, OSM
from bokeh.models import ColumnDataSource
import pandas as pd

output_file("tile.html")

# %%
dataframe = pd.read_csv("acc2.csv")
dataframe.head()

northlist = dataframe['location_easting_osgr'].tolist()
langlist = dataframe['location_northing_osgr'].tolist()

# %%
source = ColumnDataSource(
    data=dict(lat=langlist,
              lon=northlist)
)

p.circle(x="lon", y="lat", size=150, fill_color="blue", fill_alpha=0.8, source=source)
# Out:
# GlyphRenderer(id='4456', ...)

# %%
#tile_provider = get_provider(CARTODBPOSITRON)
wikimedia = get_provider(WIKIMEDIA)

# range bounds supplied in web mercator coordinates
p = figure(x_range=(-1000000, 400000), y_range=(5000000, 6000000),
           x_axis_type="mercator", y_axis_type="mercator")
p.add_tile(wikimedia)

show(p)

# %%
dataframe.head()
# Out:
#         status accident_index  accident_year accident_reference  \
# 0  Unvalidated    2.02101E+12           2021           10287148
# 1  Unvalidated    2.02101E+12           2021           10287149
# 2  Unvalidated    2.02101E+12           2021           10287151
# 3  Unvalidated    2.02101E+12           2021           10287155
# 4  Unvalidated    2.02101E+12           2021           10287157
#
#    location_easting_osgr  location_northing_osgr  longitude  latitude  \
# 0               521508.0                 19307.9        NaN       NaN
# 1               535379.0                 18078.3        NaN       NaN
# 2               529701.0                 17039.8        NaN       NaN
# 3               525312.0                 17838.5        NaN       NaN
# 4               512144.0                 17152.6        NaN       NaN
#
#    police_force  accident_severity  ...  \
# 0             1                  3  ...
# 1             1                  2  ...
# ...

# %%
p.circle(x="location_northing_osgr", y="location_easting_osgr",
         size=2,
         fill_color="dodgerblue", line_color="dodgerblue",
         fill_alpha=0.3,
         source=dataframe)

show(p)
