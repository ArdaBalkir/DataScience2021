# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Arda/OneDrive/Desktop/heart.csv')
print(df)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df = df.drop(df[df.HeartDisease == 0].index)
df = df.drop(df[df.Cholesterol == 0].index)
df.dropna()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 11    58   M           ATA        136          164          0         ST
# 13    49   M           ASY        140          234          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.plot(kind='scatter',x='RestingBP',y='Cholesterol', color = 'red')
df.plot(kind='scatter',x='RestingBP',y='Age', color = 'green')
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='Age'>

# %%
df.plot(kind='scatter',x='Age',y='Cholesterol', color = 'red')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Cholesterol'>
